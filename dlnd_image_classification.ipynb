# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 1
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 1:
# Image - Min Value: 2 Max Value: 247
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0.1
    b = 0.9
    x_min = 0
    x_max = 255
    return a + ( ( (x - x_min)*(b - a) )/( x_max - x_min ) )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,[None,*image_shape],name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,[None,n_classes],name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    i_d = int(x_tensor.shape[3])
    o_d = conv_num_outputs
    w_s = [*conv_ksize, i_d, o_d]
    w = tf.Variable(tf.random_normal(w_s, stddev=0.1))
    b = tf.Variable(tf.zeros(o_d))
    conv_strides = [1, *conv_strides, 1]
    x = tf.nn.conv2d(x_tensor, w, strides=conv_strides, padding='SAME')
    x = tf.nn.bias_add(x, b)
    x = tf.nn.relu(x)
    pool_ksize = [1, *pool_ksize, 1]
    pool_strides = [1, *pool_strides, 1]
    x = tf.nn.max_pool(x, pool_ksize, pool_strides, padding='SAME')
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    batch_size, *img_size = x_tensor.get_shape().as_list()
    img_size = img_size[0] * img_size[1] * img_size[2]
    result = tf.reshape(x_tensor, [-1, img_size])
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = (int(x_tensor.get_shape().as_list()[1]), num_outputs)
    w = tf.Variable(tf.random_normal(w_shape, stddev=0.1))
    b = tf.Variable(tf.zeros(num_outputs))
    x = tf.add(tf.matmul(x_tensor, w), b)
    x = tf.nn.relu(x)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = [int(x_tensor.get_shape().as_list()[1]), num_outputs]
    w = tf.Variable(tf.random_normal(w_shape, stddev=0.1))
    b = tf.Variable(tf.zeros(num_outputs))
    x = tf.add(tf.matmul(x_tensor, w), b)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = conv2d_maxpool(x, 32, (3, 3), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 32, (3, 3), (2, 2), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 64, (3, 3), (1, 1), (2, 2), (2, 2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x = fully_conn(x, 512)
    x = tf.nn.dropout(x, keep_prob)
    x = fully_conn(x, 128)
    x = tf.nn.dropout(x, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    o_p = output(x,10)
    
    # TODO: return output
    return o_p


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
            x: feature_batch,
            y: label_batch, keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={ x: feature_batch, y: label_batch, keep_prob: 1.0 })
    valid_accuracy = session.run(accuracy, feed_dict={ x: valid_features, y: valid_labels, keep_prob: 1.0 })
    print('The loss is: {:>10.5f} The validation accuracy is : {:0.6f}'.format(loss, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 55
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  The loss is:    2.25876 The validation accuracy is : 0.198600
# Epoch  2, CIFAR-10 Batch 1:  The loss is:    2.02157 The validation accuracy is : 0.289400
# Epoch  3, CIFAR-10 Batch 1:  The loss is:    1.93522 The validation accuracy is : 0.349800
# Epoch  4, CIFAR-10 Batch 1:  The loss is:    1.87564 The validation accuracy is : 0.361600
# Epoch  5, CIFAR-10 Batch 1:  The loss is:    1.71410 The validation accuracy is : 0.396000
# Epoch  6, CIFAR-10 Batch 1:  The loss is:    1.56336 The validation accuracy is : 0.414600
# Epoch  7, CIFAR-10 Batch 1:  The loss is:    1.46325 The validation accuracy is : 0.430400
# Epoch  8, CIFAR-10 Batch 1:  The loss is:    1.36575 The validation accuracy is : 0.444400
# Epoch  9, CIFAR-10 Batch 1:  The loss is:    1.30756 The validation accuracy is : 0.455400
# Epoch 10, CIFAR-10 Batch 1:  The loss is:    1.17373 The validation accuracy is : 0.473000
# Epoch 11, CIFAR-10 Batch 1:  The loss is:    1.10639 The validation accuracy is : 0.466800
# Epoch 12, CIFAR-10 Batch 1:  The loss is:    1.12714 The validation accuracy is : 0.466400
# Epoch 13, CIFAR-10 Batch 1:  The loss is:    1.10515 The validation accuracy is : 0.472200
# Epoch 14, CIFAR-10 Batch 1:  The loss is:    0.97913 The validation accuracy is : 0.490000
# Epoch 15, CIFAR-10 Batch 1:  The loss is:    0.90334 The validation accuracy is : 0.497000
# Epoch 16, CIFAR-10 Batch 1:  The loss is:    0.85044 The validation accuracy is : 0.514000
# Epoch 17, CIFAR-10 Batch 1:  The loss is:    0.80126 The validation accuracy is : 0.500800
# Epoch 18, CIFAR-10 Batch 1:  The loss is:    0.75032 The validation accuracy is : 0.526200
# Epoch 19, CIFAR-10 Batch 1:  The loss is:    0.70468 The validation accuracy is : 0.511600
# Epoch 20, CIFAR-10 Batch 1:  The loss is:    0.62237 The validation accuracy is : 0.524400
# Epoch 21, CIFAR-10 Batch 1:  The loss is:    0.59840 The validation accuracy is : 0.530600
# Epoch 22, CIFAR-10 Batch 1:  The loss is:    0.54703 The validation accuracy is : 0.521400
# Epoch 23, CIFAR-10 Batch 1:  The loss is:    0.49762 The validation accuracy is : 0.541200
# Epoch 24, CIFAR-10 Batch 1:  The loss is:    0.48158 The validation accuracy is : 0.536400
# Epoch 25, CIFAR-10 Batch 1:  The loss is:    0.44594 The validation accuracy is : 0.539800
# Epoch 26, CIFAR-10 Batch 1:  The loss is:    0.45511 The validation accuracy is : 0.534600
# Epoch 27, CIFAR-10 Batch 1:  The loss is:    0.40678 The validation accuracy is : 0.533200
# Epoch 28, CIFAR-10 Batch 1:  The loss is:    0.34267 The validation accuracy is : 0.534600
# Epoch 29, CIFAR-10 Batch 1:  The loss is:    0.35958 The validation accuracy is : 0.536000
# Epoch 30, CIFAR-10 Batch 1:  The loss is:    0.31983 The validation accuracy is : 0.541800
# Epoch 31, CIFAR-10 Batch 1:  The loss is:    0.29391 The validation accuracy is : 0.546400
# Epoch 32, CIFAR-10 Batch 1:  The loss is:    0.29069 The validation accuracy is : 0.543600
# Epoch 33, CIFAR-10 Batch 1:  The loss is:    0.23467 The validation accuracy is : 0.548200
# Epoch 34, CIFAR-10 Batch 1:  The loss is:    0.25076 The validation accuracy is : 0.516400
# Epoch 35, CIFAR-10 Batch 1:  The loss is:    0.21424 The validation accuracy is : 0.551000
# Epoch 36, CIFAR-10 Batch 1:  The loss is:    0.18272 The validation accuracy is : 0.538800
# Epoch 37, CIFAR-10 Batch 1:  The loss is:    0.16308 The validation accuracy is : 0.552400
# Epoch 38, CIFAR-10 Batch 1:  The loss is:    0.15701 The validation accuracy is : 0.553400
# Epoch 39, CIFAR-10 Batch 1:  The loss is:    0.12817 The validation accuracy is : 0.550400
# Epoch 40, CIFAR-10 Batch 1:  The loss is:    0.12707 The validation accuracy is : 0.544400
# Epoch 41, CIFAR-10 Batch 1:  The loss is:    0.10303 The validation accuracy is : 0.542000
# Epoch 42, CIFAR-10 Batch 1:  The loss is:    0.12825 The validation accuracy is : 0.527000
# Epoch 43, CIFAR-10 Batch 1:  The loss is:    0.11063 The validation accuracy is : 0.546400
# Epoch 44, CIFAR-10 Batch 1:  The loss is:    0.12202 The validation accuracy is : 0.546000
# Epoch 45, CIFAR-10 Batch 1:  The loss is:    0.13726 The validation accuracy is : 0.540800
# Epoch 46, CIFAR-10 Batch 1:  The loss is:    0.08860 The validation accuracy is : 0.542000
# Epoch 47, CIFAR-10 Batch 1:  The loss is:    0.08118 The validation accuracy is : 0.546000
# Epoch 48, CIFAR-10 Batch 1:  The loss is:    0.07446 The validation accuracy is : 0.556600
# Epoch 49, CIFAR-10 Batch 1:  The loss is:    0.05963 The validation accuracy is : 0.559400
# Epoch 50, CIFAR-10 Batch 1:  The loss is:    0.05195 The validation accuracy is : 0.553800
# Epoch 51, CIFAR-10 Batch 1:  The loss is:    0.05383 The validation accuracy is : 0.541000
# Epoch 52, CIFAR-10 Batch 1:  The loss is:    0.06448 The validation accuracy is : 0.543200
# Epoch 53, CIFAR-10 Batch 1:  The loss is:    0.08719 The validation accuracy is : 0.536400
# Epoch 54, CIFAR-10 Batch 1:  The loss is:    0.05821 The validation accuracy is : 0.541800
# Epoch 55, CIFAR-10 Batch 1:  The loss is:    0.04715 The validation accuracy is : 0.541800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  The loss is:    2.20827 The validation accuracy is : 0.228800
# Epoch  1, CIFAR-10 Batch 2:  The loss is:    1.97487 The validation accuracy is : 0.300600
# Epoch  1, CIFAR-10 Batch 3:  The loss is:    1.69109 The validation accuracy is : 0.353200
# Epoch  1, CIFAR-10 Batch 4:  The loss is:    1.61646 The validation accuracy is : 0.390800
# Epoch  1, CIFAR-10 Batch 5:  The loss is:    1.72912 The validation accuracy is : 0.413200
# Epoch  2, CIFAR-10 Batch 1:  The loss is:    1.74977 The validation accuracy is : 0.423800
# Epoch  2, CIFAR-10 Batch 2:  The loss is:    1.57679 The validation accuracy is : 0.414800
# Epoch  2, CIFAR-10 Batch 3:  The loss is:    1.29449 The validation accuracy is : 0.418600
# Epoch  2, CIFAR-10 Batch 4:  The loss is:    1.31125 The validation accuracy is : 0.473200
# Epoch  2, CIFAR-10 Batch 5:  The loss is:    1.49149 The validation accuracy is : 0.480800
# Epoch  3, CIFAR-10 Batch 1:  The loss is:    1.46414 The validation accuracy is : 0.499200
# Epoch  3, CIFAR-10 Batch 2:  The loss is:    1.36595 The validation accuracy is : 0.493000
# Epoch  3, CIFAR-10 Batch 3:  The loss is:    1.05596 The validation accuracy is : 0.491600
# Epoch  3, CIFAR-10 Batch 4:  The loss is:    1.12690 The validation accuracy is : 0.491000
# Epoch  3, CIFAR-10 Batch 5:  The loss is:    1.31141 The validation accuracy is : 0.511000
# Epoch  4, CIFAR-10 Batch 1:  The loss is:    1.25524 The validation accuracy is : 0.526000
# Epoch  4, CIFAR-10 Batch 2:  The loss is:    1.17617 The validation accuracy is : 0.531200
# Epoch  4, CIFAR-10 Batch 3:  The loss is:    0.92898 The validation accuracy is : 0.526000
# Epoch  4, CIFAR-10 Batch 4:  The loss is:    0.97824 The validation accuracy is : 0.533400
# Epoch  4, CIFAR-10 Batch 5:  The loss is:    1.23166 The validation accuracy is : 0.531200
# Epoch  5, CIFAR-10 Batch 1:  The loss is:    1.08501 The validation accuracy is : 0.548800
# Epoch  5, CIFAR-10 Batch 2:  The loss is:    0.99951 The validation accuracy is : 0.547400
# Epoch  5, CIFAR-10 Batch 3:  The loss is:    0.84680 The validation accuracy is : 0.550600
# Epoch  5, CIFAR-10 Batch 4:  The loss is:    0.87071 The validation accuracy is : 0.563200
# Epoch  5, CIFAR-10 Batch 5:  The loss is:    1.04751 The validation accuracy is : 0.561400
# Epoch  6, CIFAR-10 Batch 1:  The loss is:    0.94705 The validation accuracy is : 0.565600
# Epoch  6, CIFAR-10 Batch 2:  The loss is:    0.90821 The validation accuracy is : 0.571400
# Epoch  6, CIFAR-10 Batch 3:  The loss is:    0.75535 The validation accuracy is : 0.578000
# Epoch  6, CIFAR-10 Batch 4:  The loss is:    0.76845 The validation accuracy is : 0.575200
# Epoch  6, CIFAR-10 Batch 5:  The loss is:    0.91020 The validation accuracy is : 0.574000
# Epoch  7, CIFAR-10 Batch 1:  The loss is:    0.83990 The validation accuracy is : 0.585800
# Epoch  7, CIFAR-10 Batch 2:  The loss is:    0.74335 The validation accuracy is : 0.582600
# Epoch  7, CIFAR-10 Batch 3:  The loss is:    0.66090 The validation accuracy is : 0.592600
# Epoch  7, CIFAR-10 Batch 4:  The loss is:    0.67792 The validation accuracy is : 0.592200
# Epoch  7, CIFAR-10 Batch 5:  The loss is:    0.80201 The validation accuracy is : 0.581200
# Epoch  8, CIFAR-10 Batch 1:  The loss is:    0.76147 The validation accuracy is : 0.593800
# Epoch  8, CIFAR-10 Batch 2:  The loss is:    0.63002 The validation accuracy is : 0.597800
# Epoch  8, CIFAR-10 Batch 3:  The loss is:    0.61921 The validation accuracy is : 0.603800
# Epoch  8, CIFAR-10 Batch 4:  The loss is:    0.61474 The validation accuracy is : 0.609600
# Epoch  8, CIFAR-10 Batch 5:  The loss is:    0.69315 The validation accuracy is : 0.594000
# Epoch  9, CIFAR-10 Batch 1:  The loss is:    0.71049 The validation accuracy is : 0.596800
# Epoch  9, CIFAR-10 Batch 2:  The loss is:    0.60221 The validation accuracy is : 0.597200
# Epoch  9, CIFAR-10 Batch 3:  The loss is:    0.52477 The validation accuracy is : 0.600800
# Epoch  9, CIFAR-10 Batch 4:  The loss is:    0.59478 The validation accuracy is : 0.612600
# Epoch  9, CIFAR-10 Batch 5:  The loss is:    0.66347 The validation accuracy is : 0.609200
# Epoch 10, CIFAR-10 Batch 1:  The loss is:    0.64270 The validation accuracy is : 0.617800
# Epoch 10, CIFAR-10 Batch 2:  The loss is:    0.51062 The validation accuracy is : 0.606200
# Epoch 10, CIFAR-10 Batch 3:  The loss is:    0.50221 The validation accuracy is : 0.612200
# Epoch 10, CIFAR-10 Batch 4:  The loss is:    0.50813 The validation accuracy is : 0.623800
# Epoch 10, CIFAR-10 Batch 5:  The loss is:    0.57301 The validation accuracy is : 0.624200
# Epoch 11, CIFAR-10 Batch 1:  The loss is:    0.61772 The validation accuracy is : 0.630400
# Epoch 11, CIFAR-10 Batch 2:  The loss is:    0.43834 The validation accuracy is : 0.619800
# Epoch 11, CIFAR-10 Batch 3:  The loss is:    0.49143 The validation accuracy is : 0.613000
# Epoch 11, CIFAR-10 Batch 4:  The loss is:    0.45201 The validation accuracy is : 0.633400
# Epoch 11, CIFAR-10 Batch 5:  The loss is:    0.50827 The validation accuracy is : 0.631800
# Epoch 12, CIFAR-10 Batch 1:  The loss is:    0.56323 The validation accuracy is : 0.634800
# Epoch 12, CIFAR-10 Batch 2:  The loss is:    0.41073 The validation accuracy is : 0.613000
# Epoch 12, CIFAR-10 Batch 3:  The loss is:    0.41650 The validation accuracy is : 0.622800
# Epoch 12, CIFAR-10 Batch 4:  The loss is:    0.44037 The validation accuracy is : 0.631400
# Epoch 12, CIFAR-10 Batch 5:  The loss is:    0.44479 The validation accuracy is : 0.634200
# Epoch 13, CIFAR-10 Batch 1:  The loss is:    0.52692 The validation accuracy is : 0.622200
# Epoch 13, CIFAR-10 Batch 2:  The loss is:    0.39325 The validation accuracy is : 0.625600
# Epoch 13, CIFAR-10 Batch 3:  The loss is:    0.37621 The validation accuracy is : 0.638400
# Epoch 13, CIFAR-10 Batch 4:  The loss is:    0.38270 The validation accuracy is : 0.643000
# Epoch 13, CIFAR-10 Batch 5:  The loss is:    0.41823 The validation accuracy is : 0.634200
# Epoch 14, CIFAR-10 Batch 1:  The loss is:    0.45961 The validation accuracy is : 0.645600
# Epoch 14, CIFAR-10 Batch 2:  The loss is:    0.38646 The validation accuracy is : 0.644800
# Epoch 14, CIFAR-10 Batch 3:  The loss is:    0.35835 The validation accuracy is : 0.631200
# Epoch 14, CIFAR-10 Batch 4:  The loss is:    0.38254 The validation accuracy is : 0.640200
# Epoch 14, CIFAR-10 Batch 5:  The loss is:    0.41649 The validation accuracy is : 0.638400
# Epoch 15, CIFAR-10 Batch 1:  The loss is:    0.44332 The validation accuracy is : 0.645000
# Epoch 15, CIFAR-10 Batch 2:  The loss is:    0.32405 The validation accuracy is : 0.649200
# Epoch 15, CIFAR-10 Batch 3:  The loss is:    0.31926 The validation accuracy is : 0.654000
# Epoch 15, CIFAR-10 Batch 4:  The loss is:    0.38662 The validation accuracy is : 0.637000
# Epoch 15, CIFAR-10 Batch 5:  The loss is:    0.40831 The validation accuracy is : 0.652800
# Epoch 16, CIFAR-10 Batch 1:  The loss is:    0.40884 The validation accuracy is : 0.647800
# Epoch 16, CIFAR-10 Batch 2:  The loss is:    0.29411 The validation accuracy is : 0.643200
# Epoch 16, CIFAR-10 Batch 3:  The loss is:    0.30198 The validation accuracy is : 0.655000
# Epoch 16, CIFAR-10 Batch 4:  The loss is:    0.31665 The validation accuracy is : 0.651800
# Epoch 16, CIFAR-10 Batch 5:  The loss is:    0.35674 The validation accuracy is : 0.654600
# Epoch 17, CIFAR-10 Batch 1:  The loss is:    0.37000 The validation accuracy is : 0.646800
# Epoch 17, CIFAR-10 Batch 2:  The loss is:    0.30558 The validation accuracy is : 0.658000
# Epoch 17, CIFAR-10 Batch 3:  The loss is:    0.25629 The validation accuracy is : 0.661000
# Epoch 17, CIFAR-10 Batch 4:  The loss is:    0.31141 The validation accuracy is : 0.656000
# Epoch 17, CIFAR-10 Batch 5:  The loss is:    0.29370 The validation accuracy is : 0.656000
# Epoch 18, CIFAR-10 Batch 1:  The loss is:    0.34712 The validation accuracy is : 0.656800
# Epoch 18, CIFAR-10 Batch 2:  The loss is:    0.29187 The validation accuracy is : 0.651000
# Epoch 18, CIFAR-10 Batch 3:  The loss is:    0.25887 The validation accuracy is : 0.667600
# Epoch 18, CIFAR-10 Batch 4:  The loss is:    0.32515 The validation accuracy is : 0.657400
# Epoch 18, CIFAR-10 Batch 5:  The loss is:    0.28757 The validation accuracy is : 0.652800
# Epoch 19, CIFAR-10 Batch 1:  The loss is:    0.31108 The validation accuracy is : 0.665000
# Epoch 19, CIFAR-10 Batch 2:  The loss is:    0.25356 The validation accuracy is : 0.655600
# Epoch 19, CIFAR-10 Batch 3:  The loss is:    0.22591 The validation accuracy is : 0.666400
# Epoch 19, CIFAR-10 Batch 4:  The loss is:    0.27729 The validation accuracy is : 0.650000
# Epoch 19, CIFAR-10 Batch 5:  The loss is:    0.29081 The validation accuracy is : 0.652000
# Epoch 20, CIFAR-10 Batch 1:  The loss is:    0.28048 The validation accuracy is : 0.660600
# Epoch 20, CIFAR-10 Batch 2:  The loss is:    0.25460 The validation accuracy is : 0.664200
# Epoch 20, CIFAR-10 Batch 3:  The loss is:    0.19242 The validation accuracy is : 0.665000
# Epoch 20, CIFAR-10 Batch 4:  The loss is:    0.25554 The validation accuracy is : 0.666800
# Epoch 20, CIFAR-10 Batch 5:  The loss is:    0.27373 The validation accuracy is : 0.646400
# Epoch 21, CIFAR-10 Batch 1:  The loss is:    0.27679 The validation accuracy is : 0.653800
# Epoch 21, CIFAR-10 Batch 2:  The loss is:    0.25404 The validation accuracy is : 0.657200
# Epoch 21, CIFAR-10 Batch 3:  The loss is:    0.18578 The validation accuracy is : 0.663600
# Epoch 21, CIFAR-10 Batch 4:  The loss is:    0.22319 The validation accuracy is : 0.667000
# Epoch 21, CIFAR-10 Batch 5:  The loss is:    0.23843 The validation accuracy is : 0.636800
# Epoch 22, CIFAR-10 Batch 1:  The loss is:    0.27029 The validation accuracy is : 0.655000
# Epoch 22, CIFAR-10 Batch 2:  The loss is:    0.22335 The validation accuracy is : 0.654800
# Epoch 22, CIFAR-10 Batch 3:  The loss is:    0.17895 The validation accuracy is : 0.668800
# Epoch 22, CIFAR-10 Batch 4:  The loss is:    0.19614 The validation accuracy is : 0.668200
# Epoch 22, CIFAR-10 Batch 5:  The loss is:    0.22130 The validation accuracy is : 0.652800
# Epoch 23, CIFAR-10 Batch 1:  The loss is:    0.25855 The validation accuracy is : 0.647200
# Epoch 23, CIFAR-10 Batch 2:  The loss is:    0.19343 The validation accuracy is : 0.661200
# Epoch 23, CIFAR-10 Batch 3:  The loss is:    0.16717 The validation accuracy is : 0.665800
# Epoch 23, CIFAR-10 Batch 4:  The loss is:    0.18914 The validation accuracy is : 0.673400
# Epoch 23, CIFAR-10 Batch 5:  The loss is:    0.19331 The validation accuracy is : 0.648200
# Epoch 24, CIFAR-10 Batch 1:  The loss is:    0.23303 The validation accuracy is : 0.658000
# Epoch 24, CIFAR-10 Batch 2:  The loss is:    0.19000 The validation accuracy is : 0.655200
# Epoch 24, CIFAR-10 Batch 3:  The loss is:    0.17561 The validation accuracy is : 0.667800
# Epoch 24, CIFAR-10 Batch 4:  The loss is:    0.18597 The validation accuracy is : 0.668800
# Epoch 24, CIFAR-10 Batch 5:  The loss is:    0.19577 The validation accuracy is : 0.656600
# Epoch 25, CIFAR-10 Batch 1:  The loss is:    0.20353 The validation accuracy is : 0.660600
# Epoch 25, CIFAR-10 Batch 2:  The loss is:    0.18372 The validation accuracy is : 0.672000
# Epoch 25, CIFAR-10 Batch 3:  The loss is:    0.14838 The validation accuracy is : 0.663800
# Epoch 25, CIFAR-10 Batch 4:  The loss is:    0.17253 The validation accuracy is : 0.663600
# Epoch 25, CIFAR-10 Batch 5:  The loss is:    0.19456 The validation accuracy is : 0.657200
# Epoch 26, CIFAR-10 Batch 1:  The loss is:    0.18641 The validation accuracy is : 0.672000
# Epoch 26, CIFAR-10 Batch 2:  The loss is:    0.17457 The validation accuracy is : 0.668800
# Epoch 26, CIFAR-10 Batch 3:  The loss is:    0.13208 The validation accuracy is : 0.669000
# Epoch 26, CIFAR-10 Batch 4:  The loss is:    0.14892 The validation accuracy is : 0.666200
# Epoch 26, CIFAR-10 Batch 5:  The loss is:    0.17098 The validation accuracy is : 0.653400
# Epoch 27, CIFAR-10 Batch 1:  The loss is:    0.19112 The validation accuracy is : 0.667200
# Epoch 27, CIFAR-10 Batch 2:  The loss is:    0.16827 The validation accuracy is : 0.669800
# Epoch 27, CIFAR-10 Batch 3:  The loss is:    0.14481 The validation accuracy is : 0.666200
# Epoch 27, CIFAR-10 Batch 4:  The loss is:    0.15675 The validation accuracy is : 0.673400
# Epoch 27, CIFAR-10 Batch 5:  The loss is:    0.16183 The validation accuracy is : 0.644000
# Epoch 28, CIFAR-10 Batch 1:  The loss is:    0.18699 The validation accuracy is : 0.675200
# Epoch 28, CIFAR-10 Batch 2:  The loss is:    0.15811 The validation accuracy is : 0.664600
# Epoch 28, CIFAR-10 Batch 3:  The loss is:    0.14461 The validation accuracy is : 0.663400
# Epoch 28, CIFAR-10 Batch 4:  The loss is:    0.17828 The validation accuracy is : 0.665200
# Epoch 28, CIFAR-10 Batch 5:  The loss is:    0.14639 The validation accuracy is : 0.653400
# Epoch 29, CIFAR-10 Batch 1:  The loss is:    0.18216 The validation accuracy is : 0.668400
# Epoch 29, CIFAR-10 Batch 2:  The loss is:    0.18889 The validation accuracy is : 0.658200
# Epoch 29, CIFAR-10 Batch 3:  The loss is:    0.14417 The validation accuracy is : 0.644200
# Epoch 29, CIFAR-10 Batch 4:  The loss is:    0.19056 The validation accuracy is : 0.662600
# Epoch 29, CIFAR-10 Batch 5:  The loss is:    0.16230 The validation accuracy is : 0.654200
# Epoch 30, CIFAR-10 Batch 1:  The loss is:    0.16401 The validation accuracy is : 0.669800
# Epoch 30, CIFAR-10 Batch 2:  The loss is:    0.19490 The validation accuracy is : 0.659800
# Epoch 30, CIFAR-10 Batch 3:  The loss is:    0.14899 The validation accuracy is : 0.645400
# Epoch 30, CIFAR-10 Batch 4:  The loss is:    0.16414 The validation accuracy is : 0.664800
# Epoch 30, CIFAR-10 Batch 5:  The loss is:    0.16820 The validation accuracy is : 0.644200
# Epoch 31, CIFAR-10 Batch 1:  The loss is:    0.17900 The validation accuracy is : 0.664400
# Epoch 31, CIFAR-10 Batch 2:  The loss is:    0.15327 The validation accuracy is : 0.661600
# Epoch 31, CIFAR-10 Batch 3:  The loss is:    0.12578 The validation accuracy is : 0.643600
# Epoch 31, CIFAR-10 Batch 4:  The loss is:    0.14389 The validation accuracy is : 0.666600
# Epoch 31, CIFAR-10 Batch 5:  The loss is:    0.14747 The validation accuracy is : 0.648000
# Epoch 32, CIFAR-10 Batch 1:  The loss is:    0.13594 The validation accuracy is : 0.678400
# Epoch 32, CIFAR-10 Batch 2:  The loss is:    0.13413 The validation accuracy is : 0.660200
# Epoch 32, CIFAR-10 Batch 3:  The loss is:    0.11204 The validation accuracy is : 0.639800
# Epoch 32, CIFAR-10 Batch 4:  The loss is:    0.11118 The validation accuracy is : 0.676800
# Epoch 32, CIFAR-10 Batch 5:  The loss is:    0.14296 The validation accuracy is : 0.643000
# Epoch 33, CIFAR-10 Batch 1:  The loss is:    0.14830 The validation accuracy is : 0.669400
# Epoch 33, CIFAR-10 Batch 2:  The loss is:    0.16313 The validation accuracy is : 0.659200
# Epoch 33, CIFAR-10 Batch 3:  The loss is:    0.12492 The validation accuracy is : 0.638600
# Epoch 33, CIFAR-10 Batch 4:  The loss is:    0.11314 The validation accuracy is : 0.668800
# Epoch 33, CIFAR-10 Batch 5:  The loss is:    0.11861 The validation accuracy is : 0.643400
# Epoch 34, CIFAR-10 Batch 1:  The loss is:    0.15522 The validation accuracy is : 0.665400
# Epoch 34, CIFAR-10 Batch 2:  The loss is:    0.12738 The validation accuracy is : 0.667600
# Epoch 34, CIFAR-10 Batch 3:  The loss is:    0.10053 The validation accuracy is : 0.656800
# Epoch 34, CIFAR-10 Batch 4:  The loss is:    0.11724 The validation accuracy is : 0.668200
# Epoch 34, CIFAR-10 Batch 5:  The loss is:    0.11464 The validation accuracy is : 0.650600
# Epoch 35, CIFAR-10 Batch 1:  The loss is:    0.14200 The validation accuracy is : 0.670800
# Epoch 35, CIFAR-10 Batch 2:  The loss is:    0.17027 The validation accuracy is : 0.662600
# Epoch 35, CIFAR-10 Batch 3:  The loss is:    0.08740 The validation accuracy is : 0.652600
# Epoch 35, CIFAR-10 Batch 4:  The loss is:    0.09830 The validation accuracy is : 0.680400
# Epoch 35, CIFAR-10 Batch 5:  The loss is:    0.12124 The validation accuracy is : 0.648800
# Epoch 36, CIFAR-10 Batch 1:  The loss is:    0.13230 The validation accuracy is : 0.667200
# Epoch 36, CIFAR-10 Batch 2:  The loss is:    0.12257 The validation accuracy is : 0.666600
# Epoch 36, CIFAR-10 Batch 3:  The loss is:    0.08568 The validation accuracy is : 0.661200
# Epoch 36, CIFAR-10 Batch 4:  The loss is:    0.11882 The validation accuracy is : 0.676200
# Epoch 36, CIFAR-10 Batch 5:  The loss is:    0.11430 The validation accuracy is : 0.646400
# Epoch 37, CIFAR-10 Batch 1:  The loss is:    0.10842 The validation accuracy is : 0.665200
# Epoch 37, CIFAR-10 Batch 2:  The loss is:    0.12556 The validation accuracy is : 0.671200
# Epoch 37, CIFAR-10 Batch 3:  The loss is:    0.07851 The validation accuracy is : 0.660400
# Epoch 37, CIFAR-10 Batch 4:  The loss is:    0.11193 The validation accuracy is : 0.658400
# Epoch 37, CIFAR-10 Batch 5:  The loss is:    0.11808 The validation accuracy is : 0.648000
# Epoch 38, CIFAR-10 Batch 1:  The loss is:    0.11624 The validation accuracy is : 0.670800
# Epoch 38, CIFAR-10 Batch 2:  The loss is:    0.11760 The validation accuracy is : 0.662000
# Epoch 38, CIFAR-10 Batch 3:  The loss is:    0.08990 The validation accuracy is : 0.648800
# Epoch 38, CIFAR-10 Batch 4:  The loss is:    0.08710 The validation accuracy is : 0.659000
# Epoch 38, CIFAR-10 Batch 5:  The loss is:    0.11473 The validation accuracy is : 0.646200
# Epoch 39, CIFAR-10 Batch 1:  The loss is:    0.11363 The validation accuracy is : 0.662800
# Epoch 39, CIFAR-10 Batch 2:  The loss is:    0.11401 The validation accuracy is : 0.667200
# Epoch 39, CIFAR-10 Batch 3:  The loss is:    0.09210 The validation accuracy is : 0.669800
# Epoch 39, CIFAR-10 Batch 4:  The loss is:    0.09003 The validation accuracy is : 0.664200
# Epoch 39, CIFAR-10 Batch 5:  The loss is:    0.10483 The validation accuracy is : 0.653200
# Epoch 40, CIFAR-10 Batch 1:  The loss is:    0.10853 The validation accuracy is : 0.669000
# Epoch 40, CIFAR-10 Batch 2:  The loss is:    0.09653 The validation accuracy is : 0.665000
# Epoch 40, CIFAR-10 Batch 3:  The loss is:    0.09167 The validation accuracy is : 0.665200
# Epoch 40, CIFAR-10 Batch 4:  The loss is:    0.12397 The validation accuracy is : 0.661600
# Epoch 40, CIFAR-10 Batch 5:  The loss is:    0.09664 The validation accuracy is : 0.661000
# Epoch 41, CIFAR-10 Batch 1:  The loss is:    0.13490 The validation accuracy is : 0.664400
# Epoch 41, CIFAR-10 Batch 2:  The loss is:    0.10440 The validation accuracy is : 0.658200
# Epoch 41, CIFAR-10 Batch 3:  The loss is:    0.07220 The validation accuracy is : 0.667600
# Epoch 41, CIFAR-10 Batch 4:  The loss is:    0.07216 The validation accuracy is : 0.665400
# Epoch 41, CIFAR-10 Batch 5:  The loss is:    0.10342 The validation accuracy is : 0.658800
# Epoch 42, CIFAR-10 Batch 1:  The loss is:    0.12206 The validation accuracy is : 0.670200
# Epoch 42, CIFAR-10 Batch 2:  The loss is:    0.11433 The validation accuracy is : 0.654800
# Epoch 42, CIFAR-10 Batch 3:  The loss is:    0.07978 The validation accuracy is : 0.660800
# Epoch 42, CIFAR-10 Batch 4:  The loss is:    0.06984 The validation accuracy is : 0.655800
# Epoch 42, CIFAR-10 Batch 5:  The loss is:    0.10186 The validation accuracy is : 0.650400
# Epoch 43, CIFAR-10 Batch 1:  The loss is:    0.09431 The validation accuracy is : 0.658800
# Epoch 43, CIFAR-10 Batch 2:  The loss is:    0.09743 The validation accuracy is : 0.653800
# Epoch 43, CIFAR-10 Batch 3:  The loss is:    0.07549 The validation accuracy is : 0.660000
# Epoch 43, CIFAR-10 Batch 4:  The loss is:    0.07504 The validation accuracy is : 0.669000
# Epoch 43, CIFAR-10 Batch 5:  The loss is:    0.09080 The validation accuracy is : 0.670200
# Epoch 44, CIFAR-10 Batch 1:  The loss is:    0.11268 The validation accuracy is : 0.664400
# Epoch 44, CIFAR-10 Batch 2:  The loss is:    0.09672 The validation accuracy is : 0.656000
# Epoch 44, CIFAR-10 Batch 3:  The loss is:    0.06569 The validation accuracy is : 0.664600
# Epoch 44, CIFAR-10 Batch 4:  The loss is:    0.07177 The validation accuracy is : 0.666400
# Epoch 44, CIFAR-10 Batch 5:  The loss is:    0.07830 The validation accuracy is : 0.673200
# Epoch 45, CIFAR-10 Batch 1:  The loss is:    0.08530 The validation accuracy is : 0.663800
# Epoch 45, CIFAR-10 Batch 2:  The loss is:    0.08620 The validation accuracy is : 0.668000
# Epoch 45, CIFAR-10 Batch 3:  The loss is:    0.07219 The validation accuracy is : 0.666400
# Epoch 45, CIFAR-10 Batch 4:  The loss is:    0.08510 The validation accuracy is : 0.667000
# Epoch 45, CIFAR-10 Batch 5:  The loss is:    0.08653 The validation accuracy is : 0.670800
# Epoch 46, CIFAR-10 Batch 1:  The loss is:    0.10249 The validation accuracy is : 0.648600
# Epoch 46, CIFAR-10 Batch 2:  The loss is:    0.09417 The validation accuracy is : 0.655200
# Epoch 46, CIFAR-10 Batch 3:  The loss is:    0.07795 The validation accuracy is : 0.672400
# Epoch 46, CIFAR-10 Batch 4:  The loss is:    0.06540 The validation accuracy is : 0.663800
# Epoch 46, CIFAR-10 Batch 5:  The loss is:    0.07080 The validation accuracy is : 0.670400
# Epoch 47, CIFAR-10 Batch 1:  The loss is:    0.10965 The validation accuracy is : 0.656200
# Epoch 47, CIFAR-10 Batch 2:  The loss is:    0.08904 The validation accuracy is : 0.665200
# Epoch 47, CIFAR-10 Batch 3:  The loss is:    0.07103 The validation accuracy is : 0.676000
# Epoch 47, CIFAR-10 Batch 4:  The loss is:    0.07334 The validation accuracy is : 0.649000
# Epoch 47, CIFAR-10 Batch 5:  The loss is:    0.08679 The validation accuracy is : 0.667600
# Epoch 48, CIFAR-10 Batch 1:  The loss is:    0.09730 The validation accuracy is : 0.650400
# Epoch 48, CIFAR-10 Batch 2:  The loss is:    0.07612 The validation accuracy is : 0.655800
# Epoch 48, CIFAR-10 Batch 3:  The loss is:    0.06553 The validation accuracy is : 0.669800
# Epoch 48, CIFAR-10 Batch 4:  The loss is:    0.08424 The validation accuracy is : 0.642800
# Epoch 48, CIFAR-10 Batch 5:  The loss is:    0.10162 The validation accuracy is : 0.663000
# Epoch 49, CIFAR-10 Batch 1:  The loss is:    0.10783 The validation accuracy is : 0.656200
# Epoch 49, CIFAR-10 Batch 2:  The loss is:    0.08275 The validation accuracy is : 0.656600
# Epoch 49, CIFAR-10 Batch 3:  The loss is:    0.06452 The validation accuracy is : 0.667600
# Epoch 49, CIFAR-10 Batch 4:  The loss is:    0.06470 The validation accuracy is : 0.647000
# Epoch 49, CIFAR-10 Batch 5:  The loss is:    0.10684 The validation accuracy is : 0.659800
# Epoch 50, CIFAR-10 Batch 1:  The loss is:    0.09491 The validation accuracy is : 0.662000
# Epoch 50, CIFAR-10 Batch 2:  The loss is:    0.06347 The validation accuracy is : 0.663200
# Epoch 50, CIFAR-10 Batch 3:  The loss is:    0.06492 The validation accuracy is : 0.672200
# Epoch 50, CIFAR-10 Batch 4:  The loss is:    0.05677 The validation accuracy is : 0.645800
# Epoch 50, CIFAR-10 Batch 5:  The loss is:    0.07985 The validation accuracy is : 0.661400
# Epoch 51, CIFAR-10 Batch 1:  The loss is:    0.09820 The validation accuracy is : 0.654200
# Epoch 51, CIFAR-10 Batch 2:  The loss is:    0.04942 The validation accuracy is : 0.669000
# Epoch 51, CIFAR-10 Batch 3:  The loss is:    0.04942 The validation accuracy is : 0.670200
# Epoch 51, CIFAR-10 Batch 4:  The loss is:    0.05181 The validation accuracy is : 0.657200
# Epoch 51, CIFAR-10 Batch 5:  The loss is:    0.06018 The validation accuracy is : 0.664800
# Epoch 52, CIFAR-10 Batch 1:  The loss is:    0.06343 The validation accuracy is : 0.673600
# Epoch 52, CIFAR-10 Batch 2:  The loss is:    0.04854 The validation accuracy is : 0.680200
# Epoch 52, CIFAR-10 Batch 3:  The loss is:    0.04558 The validation accuracy is : 0.673800
# Epoch 52, CIFAR-10 Batch 4:  The loss is:    0.05259 The validation accuracy is : 0.648000
# Epoch 52, CIFAR-10 Batch 5:  The loss is:    0.06123 The validation accuracy is : 0.669000
# Epoch 53, CIFAR-10 Batch 1:  The loss is:    0.08150 The validation accuracy is : 0.652200
# Epoch 53, CIFAR-10 Batch 2:  The loss is:    0.05869 The validation accuracy is : 0.677400
# Epoch 53, CIFAR-10 Batch 3:  The loss is:    0.05801 The validation accuracy is : 0.672000
# Epoch 53, CIFAR-10 Batch 4:  The loss is:    0.05092 The validation accuracy is : 0.655800
# Epoch 53, CIFAR-10 Batch 5:  The loss is:    0.05256 The validation accuracy is : 0.667800
# Epoch 54, CIFAR-10 Batch 1:  The loss is:    0.06700 The validation accuracy is : 0.663000
# Epoch 54, CIFAR-10 Batch 2:  The loss is:    0.04812 The validation accuracy is : 0.669400
# Epoch 54, CIFAR-10 Batch 3:  The loss is:    0.04948 The validation accuracy is : 0.665600
# Epoch 54, CIFAR-10 Batch 4:  The loss is:    0.06028 The validation accuracy is : 0.652000
# Epoch 54, CIFAR-10 Batch 5:  The loss is:    0.05824 The validation accuracy is : 0.670800
# Epoch 55, CIFAR-10 Batch 1:  The loss is:    0.06428 The validation accuracy is : 0.661200
# Epoch 55, CIFAR-10 Batch 2:  The loss is:    0.04126 The validation accuracy is : 0.673200
# Epoch 55, CIFAR-10 Batch 3:  The loss is:    0.04008 The validation accuracy is : 0.667200
# Epoch 55, CIFAR-10 Batch 4:  The loss is:    0.05831 The validation accuracy is : 0.667200
# Epoch 55, CIFAR-10 Batch 5:  The loss is:    0.05191 The validation accuracy is : 0.666800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.66865234375

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
